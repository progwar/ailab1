# %% [markdown]
# # Практическое задание №1
#
# **Жирный текст** и *курсив*
#
# Нумерованный список:
# 1. Первое
# 2. Второе
# 3. Третье
#
# Маркированный список:
# - Первое
# - Второе
# - Третье
#
# Преобразование Лапласа функции:
# $$F(p) = \int_0^\infty e^{-pt}f(t)dt$$
#
#
# Изображение:
# ![Алекси Лайхо](https://i.pinimg.com/736x/10/e3/d5/10e3d51b83f632008111ebd9c7d15146.jpg)

# %%
name = input("Введите имя")
print(f"Привет, {name}! Добро пожаловать в JupyterLab!")
# Out:
# Введите имя Ив
# Привет, Ив! Добро пожаловать в JupyterLab!
