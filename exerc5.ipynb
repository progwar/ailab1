# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/MyDrive/my_text_file.txt"
with open(file_path, "w") as f:
  f.write("Это тестовый файл, сохранённый в Google Drive.\n")
  f.write("Вторая строка текста")

print("Файл успешно сохранён в Google Drive.")
# Out:
# Файл успешно сохранён в Google Drive.

# %%
with open(file_path, "r") as f:
  content = f.read()
  print("Содержание файла:\n", content)
# Out:
# Содержание файла:
#  Это тестовый файл, сохранённый в Google Drive.
# Вторая строка текста

# %%
students = [
    ["Червиченко И.Д.", 19, "ИВТ-б-о-24-2"],
    ["Ганиев Д.В.", 19, "ИВТ-б-о-24-2"],
    ["Прохоров В.И.", 20, "ИВТ-б-о-24-2"],
]

csv_path = "/content/drive/MyDrive/students.csv"
with open(csv_path, "w") as f:
  for student in students:
    f.write(",".join(map(str, student)) + "\n")
