# %%
# %%time
import time
for i in range(50):
    time.sleep(0.1)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 5.07 s

# %%
# %timeit x = [(i**10) for i in range(10)]
# Out:
# 1.88 μs ± 57.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
