# %%
# !dir
# Out:
#  Том в устройстве C не имеет метки.
#  Серийный номер тома: 2CD8-C8FD
#
#  Содержимое папки C:\Users\mrkon\lab1ex
#
# 23.03.2026  22:54    <DIR>          .
# 23.03.2026  22:54    <DIR>          ..
# 23.03.2026  22:24    <DIR>          .ipynb_checkpoints
# 22.03.2026  23:22             2 035 ex1.ipynb
# 22.03.2026  23:40            24 175 ex2.ipynb
# 22.03.2026  23:46             1 270 ex3.ipynb
# 22.03.2026  23:55               957 ex4.ipynb
# 22.03.2026  23:56               838 ex5.ipynb
# 22.03.2026  23:58               872 ex6.ipynb
# 23.03.2026  00:04            40 139 ex7.ipynb
# 23.03.2026  02:02             1 856 exerc1.ipynb
# 23.03.2026  02:14             1 695 exerc2.ipynb
# 23.03.2026  22:38             8 104 exerc3.ipynb
# 23.03.2026  22:15               242 script.py
# 23.03.2026  22:54             1 976 Untitled.ipynb
#               12 файлов         84 159 байт
#                3 папок   7 095 545 856 байт свободно

# %%
# !where python
# Out:
# D:\aconda\python.exe
# C:\Users\mrkon\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !mkdir test_folder

# %%
# !rmdir test_folder

# %%
# !clear
